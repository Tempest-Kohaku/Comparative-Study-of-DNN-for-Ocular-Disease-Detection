# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    precision_recall_fscore_support
)
import time
import logging

# --------------------- Optional: Mixed Precision ---------------------
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')
# ---------------------------------------------------------------------

# --------------------- Optimizations ---------------------
AUTOTUNE = tf.data.AUTOTUNE
SHUFFLE_BUFFER = 250  # Increased shuffle buffer for more randomness
# ---------------------------------------------------------------------

# Set up logging for any preprocessing errors
logging.basicConfig(filename="preprocessing_errors.log", level=logging.ERROR)

# Define paths
base_folder = r"C:\Users\Manas\IoT Research Models\ODIR-5K\ODIR-5K"
xlsx_path = r"C:\Users\Manas\IoT Research Models\full_df.xlsx"  # Dataset Excel file

# Load the dataset
df = pd.read_excel(xlsx_path)
labels_list = ['N', 'D', 'G', 'C', 'A', 'H', 'M', 'O']
df['target'] = df[labels_list].idxmax(axis=1)

# Prepare image file paths and corresponding targets
left_paths = df['Left-Fundus'].dropna().tolist()
right_paths = df['Right-Fundus'].dropna().tolist()
all_paths = left_paths + right_paths
patient_targets = df['target'].dropna().tolist()
all_targets = patient_targets + patient_targets  # Duplicate for left & right images

# Filter out invalid paths
valid_paths = [p for p in all_paths if os.path.isfile(p)]
if len(valid_paths) == 0:
    raise ValueError("No valid images found. Please check the dataset.")

# Map textual labels to integer indices
label_to_index = {label: idx for idx, label in enumerate(labels_list)}
target_indices = [label_to_index[label] for label in all_targets]

# Split dataset into training and validation sets
X_train_paths, X_val_paths, y_train, y_val = train_test_split(
    valid_paths, target_indices, test_size=0.2, random_state=42
)
# One-hot encode labels
y_train = to_categorical(y_train, num_classes=8)
y_val = to_categorical(y_val, num_classes=8)

# --- Build tf.data Pipeline ---
IMG_SIZE = 224
BATCH_SIZE = 32  # Reduced batch size to reduce memory usage

def process_image(file_path, label):
    image = tf.io.read_file(file_path)
    try:
        image = tf.image.decode_jpeg(image, channels=3)
    except Exception as e:
        tf.print(f"Error decoding {file_path}: {e}")
        image = tf.zeros([IMG_SIZE, IMG_SIZE, 3], dtype=tf.uint8)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    return image, label

def augment(image, label):
    image = tf.image.resize_with_crop_or_pad(image, IMG_SIZE+20, IMG_SIZE+20)
    image = tf.image.random_crop(image, size=[IMG_SIZE, IMG_SIZE, 3])
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    return image, label

def normalize(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def create_dataset(file_paths, labels, training=True):
    ds = tf.data.Dataset.from_tensor_slices((file_paths, labels))
    ds = ds.map(process_image, num_parallel_calls=AUTOTUNE)
    if training:
        ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
    ds = ds.map(normalize, num_parallel_calls=AUTOTUNE)
    if training:
        ds = ds.shuffle(SHUFFLE_BUFFER)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.cache().prefetch(AUTOTUNE)
    return ds

train_ds = create_dataset(X_train_paths, y_train, training=True)
val_ds = create_dataset(X_val_paths, y_val, training=False)

# Diagnostic: Check one batch
start = time.time()
for batch in train_ds.take(1):
    images_batch, labels_batch = batch
    print("One batch shape:", images_batch.shape)
end = time.time()
print("Time taken for one batch:", end - start, "seconds")

# --- Build the Model ---
base_model = DenseNet121(weights="imagenet", include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model.trainable = False  # Freeze base model initially

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(8, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# --- Training ---
print("Starting training...")
start_time = time.time()
history = model.fit(
    train_ds,
    epochs=50,
    validation_data=val_ds,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)
training_time = time.time() - start_time

# Save the model
model.save("ocular_disease_densenet121_model.h5")
print("✅ Model saved as 'ocular_disease_densenet121_model.h5'")

# --- Evaluation ---
loss, val_accuracy = model.evaluate(val_ds, verbose=1)
print(f"✅ Validation Accuracy: {val_accuracy*100:.2f}%")

# Predictions for metrics
y_pred = model.predict(val_ds)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(np.concatenate([y for _, y in val_ds], axis=0), axis=1)

# Additional Metrics
roc_score = roc_auc_score(np.concatenate([y for _, y in val_ds], axis=0), y_pred, multi_class='ovr')
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true, y_pred_classes, average='weighted')

# Number of Parameters and Layers
num_params = model.count_params()
num_layers = len(model.layers)

print("\n--- Metrics for Comparative Study ---")
print(f"Accuracy: {val_accuracy:.4f}")
print(f"ROC AUC Score: {roc_score:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"Number of Parameters: {num_params}")
print(f"Training Time: {training_time:.2f} seconds")
print(f"Number of Layers: {num_layers}")

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred_classes))

print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=labels_list))
# Out:
# One batch shape: (32, 224, 224, 3)
# Time taken for one batch: 0.40424036979675293 seconds
# Starting training...
# Epoch 1/50
# 320/320 [==============================] - 72s 166ms/step - loss: 1.5743 - accuracy: 0.3990 - val_loss: 1.3328 - val_accuracy: 0.4975 - lr: 1.0000e-04
# Epoch 2/50
# 320/320 [==============================] - 46s 144ms/step - loss: 1.3620 - accuracy: 0.4659 - val_loss: 1.2537 - val_accuracy: 0.5229 - lr: 1.0000e-04
# Epoch 3/50
# 320/320 [==============================] - 58s 183ms/step - loss: 1.2792 - accuracy: 0.4975 - val_loss: 1.2249 - val_accuracy: 0.5315 - lr: 1.0000e-04
# Epoch 4/50
# 320/320 [==============================] - 59s 186ms/step - loss: 1.2280 - accuracy: 0.5139 - val_loss: 1.1970 - val_accuracy: 0.5428 - lr: 1.0000e-04
# Epoch 5/50
# 320/320 [==============================] - 60s 188ms/step - loss: 1.1705 - accuracy: 0.5397 - val_loss: 1.1772 - val_accuracy: 0.5440 - lr: 1.0000e-04
# Epoch 6/50
# 320/320 [==============================] - 60s 189ms/step - loss: 1.1336 - accuracy: 0.5494 - val_loss: 1.1637 - val_accuracy: 0.5577 - lr: 1.0000e-04
# Epoch 7/50
# 320/320 [==============================] - 60s 188ms/step - loss: 1.0908 - accuracy: 0.5728 - val_loss: 1.1500 - val_accuracy: 0.5671 - lr: 1.0000e-04
# Epoch 8/50
# 320/320 [==============================] - 59s 185ms/step - loss: 1.0508 - accuracy: 0.5879 - val_loss: 1.1321 - val_accuracy: 0.5741 - lr: 1.0000e-04
# Epoch 9/50
# 320/320 [==============================] - 60s 188ms/step - loss: 1.0090 - accuracy: 0.6066 - val_loss: 1.1161 - val_accuracy: 0.5839 - lr: 1.0000e-04
# Epoch 10/50
# 320/320 [==============================] - 59s 185ms/step - loss: 0.9595 - accuracy: 0.6251 - val_loss: 1.1085 - val_accuracy: 0.5843 - lr: 1.0000e-04
# Epoch 11/50
# 320/320 [==============================] - 60s 187ms/step - loss: 0.9306 - accuracy: 0.6432 - val_loss: 1.0965 - val_accuracy: 0.5847 - lr: 1.0000e-04
# Epoch 12/50
# 320/320 [==============================] - 60s 187ms/step - loss: 0.8981 - accuracy: 0.6454 - val_loss: 1.0905 - val_accuracy: 0.5901 - lr: 1.0000e-04
# Epoch 13/50
# 320/320 [==============================] - 53s 165ms/step - loss: 0.8526 - accuracy: 0.6667 - val_loss: 1.0827 - val_accuracy: 0.5921 - lr: 1.0000e-04
# Epoch 14/50
# 320/320 [==============================] - 43s 135ms/step - loss: 0.8160 - accuracy: 0.6838 - val_loss: 1.0615 - val_accuracy: 0.6023 - lr: 1.0000e-04
# Epoch 15/50
# 320/320 [==============================] - 44s 136ms/step - loss: 0.7708 - accuracy: 0.7046 - val_loss: 1.0524 - val_accuracy: 0.6081 - lr: 1.0000e-04
# Epoch 16/50
# 320/320 [==============================] - 44s 137ms/step - loss: 0.7349 - accuracy: 0.7138 - val_loss: 1.0431 - val_accuracy: 0.6124 - lr: 1.0000e-04
# Epoch 17/50
# 320/320 [==============================] - 44s 138ms/step - loss: 0.7033 - accuracy: 0.7317 - val_loss: 1.0424 - val_accuracy: 0.6113 - lr: 1.0000e-04
# Epoch 18/50
# 320/320 [==============================] - 44s 138ms/step - loss: 0.6654 - accuracy: 0.7437 - val_loss: 1.0208 - val_accuracy: 0.6226 - lr: 1.0000e-04
# Epoch 19/50
# 320/320 [==============================] - 44s 137ms/step - loss: 0.6148 - accuracy: 0.7658 - val_loss: 1.0284 - val_accuracy: 0.6195 - lr: 1.0000e-04
# Epoch 20/50
# 320/320 [==============================] - 44s 136ms/step - loss: 0.5914 - accuracy: 0.7753 - val_loss: 1.0245 - val_accuracy: 0.6281 - lr: 1.0000e-04
# Epoch 21/50
# 320/320 [==============================] - 45s 140ms/step - loss: 0.5534 - accuracy: 0.7913 - val_loss: 1.0204 - val_accuracy: 0.6386 - lr: 1.0000e-04
# Epoch 22/50
# 320/320 [==============================] - 45s 139ms/step - loss: 0.5313 - accuracy: 0.8026 - val_loss: 1.0148 - val_accuracy: 0.6441 - lr: 1.0000e-04
# Epoch 23/50
# 320/320 [==============================] - 44s 137ms/step - loss: 0.4841 - accuracy: 0.8221 - val_loss: 1.0139 - val_accuracy: 0.6531 - lr: 1.0000e-04
# Epoch 24/50
# 320/320 [==============================] - 45s 140ms/step - loss: 0.4527 - accuracy: 0.8391 - val_loss: 1.0073 - val_accuracy: 0.6621 - lr: 1.0000e-04
# Epoch 25/50
# 320/320 [==============================] - 44s 137ms/step - loss: 0.4248 - accuracy: 0.8432 - val_loss: 1.0193 - val_accuracy: 0.6590 - lr: 1.0000e-04
# Epoch 26/50
# 320/320 [==============================] - 44s 137ms/step - loss: 0.4019 - accuracy: 0.8525 - val_loss: 1.0331 - val_accuracy: 0.6574 - lr: 1.0000e-04
# Epoch 27/50
# 320/320 [==============================] - 43s 135ms/step - loss: 0.3755 - accuracy: 0.8655 - val_loss: 1.0260 - val_accuracy: 0.6672 - lr: 1.0000e-04
# Epoch 28/50
# 320/320 [==============================] - 44s 137ms/step - loss: 0.3295 - accuracy: 0.8864 - val_loss: 1.0175 - val_accuracy: 0.6633 - lr: 5.0000e-05
# Epoch 29/50
# 320/320 [==============================] - 37s 116ms/step - loss: 0.3070 - accuracy: 0.8946 - val_loss: 1.0147 - val_accuracy: 0.6750 - lr: 5.0000e-05
# ✅ Model saved as 'ocular_disease_densenet121_model.h5'
# 80/80 [==============================] - 6s 74ms/step - loss: 1.0073 - accuracy: 0.6621
# ✅ Validation Accuracy: 66.21%
# 80/80 [==============================] - 8s 73ms/step
#
# --- Metrics for Comparative Study ---
# Accuracy: 0.6621
# ROC AUC Score: 0.9048
# Precision: 0.6585
# Recall: 0.6621
# F1 Score: 0.6553
# Number of Parameters: 8620104
# Training Time: 1464.11 seconds
# Number of Layers: 8
#
# Confusion Matrix:
# [[620 146  21  12   5   0   1  43]
#  [172 606   9   7  11   4   7  38]
#  [ 29  20  82   7   1   0   6   2]
#  [ 18   5   3  99   0   0   2   3]
#  [ 17  18   0   0  42   0   1  17]
#  [  2  13   1   0   0  12   0   1]
#  [  4   3   0   2   1   0 100   1]
#  [103  93   2   7   5   0   1 132]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.64      0.73      0.68       848
#            D       0.67      0.71      0.69       854
#            G       0.69      0.56      0.62       147
#            C       0.74      0.76      0.75       130
#            A       0.65      0.44      0.53        95
#            H       0.75      0.41      0.53        29
#            M       0.85      0.90      0.87       111
#            O       0.56      0.38      0.46       343
#
#     accuracy                           0.66      2557
#    macro avg       0.69      0.61      0.64      2557
# weighted avg       0.66      0.66      0.66      2557

# %%
metrics = {
    "Accuracy": val_accuracy,
    "ROC Score": roc_score,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1_score,
    "Number of Parameters": num_params,
    "Training Time (seconds)": training_time,
    "Number of Layers": num_layers
}

# Save metrics to a CSV file
metrics_df = pd.DataFrame([metrics])
metrics_df.to_csv("Model_metrics_DenseNet121.csv", index=False)
print("✅ Metrics saved to 'Model_metrics_DenseNet121.csv'")
# Out:
# ✅ Metrics saved to 'Model_metrics_DenseNet121.csv'

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model  # Correctly import load_model

# Load your model
model = load_model("ocular_disease_DenseNet121_model.h5")

# Save model summary to a text file
with open('model_summary_DenseNet121.txt', 'w') as f:
    model.summary(print_fn=lambda x: f.write(x + '\n'))
print("Model summary saved to 'model_summary_DenseNet121.txt'.")

# Plot training curves
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title("Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.savefig('DenseNet121_eval.png')  # Save the training curves plot
print("Training curves saved to 'DenseNet121_eval.png'.")
plt.show()
# Out:
# Model summary saved to 'model_summary_DenseNet121.txt'.
# Training curves saved to 'DenseNet121_eval.png'.

# %%
last_epoch_accuracy = history.history['accuracy'][-1]
print(f"Accuracy at the last epoch: {last_epoch_accuracy:.4f}")
# Out:
# Accuracy at the last epoch: 0.8946

# %%
import tensorflow as tf
print("GPUs available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
